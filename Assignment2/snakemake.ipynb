# %%
# Define the command to run Snakemake
# !snakemake -c1 -d /data/leuven/362/vsc36251/Assignment2/snakemakeOutput -s /data/leuven/362/vsc36251/Assignment2/snakefile > snakemake_output.log 2>&1

with open("snakemake_output.log", "r") as file:
    log_contents = file.read()

# Print the contents of the file
print(log_contents)
# Out:
# Building DAG of jobs...
# Using shell: /lustre1/project/stg_00079/teaching/I0U19a_conda_2024/bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job              count
# -------------  -------
# SNP_calling          1
# SNP_norm_filt        1
# all                  1
# bwa                  1
# fastqc               1
# snpeff               1
# total                6
#
# Select jobs to execute...
#
# [Wed May  1 12:15:55 2024]
# rule bwa:
#     input: /staging/leuven/stg_00079/teaching/1000genomes/HG00141.GRCh38DH.exome.chr21.fq.gz
#     output: 2_bwa/HG00141.GRCh38DH.exome.chr21.bam, 2_bwa/HG00141.GRCh38DH.exome.chr21.bam.bai
#     jobid: 5
#     reason: Missing output files: 2_bwa/HG00141.GRCh38DH.exome.chr21.bam
#     wildcards: sample=HG00141.GRCh38DH.exome.chr21
#     resources: tmpdir=/tmp
#
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 99010 sequences (10000010 bp)...
# ...
